# %% [markdown]
# ## using pandas -- get_dummies
# ## using sklearn -- OneHotEncod

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Prasa'

# %%
os.chdir("C:\\Users\\Prasa\\OneDrive\\Documents")

# %%
df = pd.read_csv("dummy_variables.csv")
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9      robbinsville  2600  575000
# 10     robbinsville  2900  600000
# 11     robbinsville  3100  620000
# 12     robbinsville  3600  695000

# %%
dff = pd.read_csv("dummy_variables.csv")
dff
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9      robbinsville  2600  575000
# 10     robbinsville  2900  600000
# 11     robbinsville  3100  620000
# 12     robbinsville  3600  695000

# %% [markdown]
# ### Q. Build a predictor function to predict price of a home :
# ### 1) with 3400sqft area in west windsor
# ### 2) with 2800sqft home in robbinsville

# %%
df.head()
# Out:
#               town  area   price
# 0  monroe township  2600  550000
# 1  monroe township  3000  565000
# 2  monroe township  3200  610000
# 3  monroe township  3600  680000
# 4  monroe township  4000  725000

# %% [markdown]
# ### get_dummies() is used for data manipulation. It converts categorical data into dummy or indicator variables.

# %%
dummies = pd.get_dummies(df.town)
dummies
# Out:
#     monroe township  robbinsville  west windsor
# 0                 1             0             0
# 1                 1             0             0
# 2                 1             0             0
# 3                 1             0             0
# 4                 1             0             0
# 5                 0             0             1
# 6                 0             0             1
# 7                 0             0             1
# 8                 0             0             1
# 9                 0             1             0
# 10                0             1             0
# 11                0             1             0
# 12                0             1             0

# %%
# now concate the both dataframes...
merg = pd.concat([df,dummies],axis="columns")
merg
# Out:
#                town  area   price  monroe township  robbinsville  west windsor
# 0   monroe township  2600  550000                1             0             0
# 1   monroe township  3000  565000                1             0             0
# 2   monroe township  3200  610000                1             0             0
# 3   monroe township  3600  680000                1             0             0
# 4   monroe township  4000  725000                1             0             0
# 5      west windsor  2600  585000                0             0             1
# 6      west windsor  2800  615000                0             0             1
# 7      west windsor  3300  650000                0             0             1
# 8      west windsor  3600  710000                0             0             1
# 9      robbinsville  2600  575000                0             1             0
# 10     robbinsville  2900  600000                0             1             0
# ...

# %%
# now theres no use of town column...
# so we can drop that column...
# and also we can drop one of the town from the dummies...

# %%
final = merg.drop(['town','west windsor'],axis = "columns")
final
# Out:
#     area   price  monroe township  robbinsville
# 0   2600  550000                1             0
# 1   3000  565000                1             0
# 2   3200  610000                1             0
# 3   3600  680000                1             0
# 4   4000  725000                1             0
# 5   2600  585000                0             0
# 6   2800  615000                0             0
# 7   3300  650000                0             0
# 8   3600  710000                0             0
# 9   2600  575000                0             1
# 10  2900  600000                0             1
# 11  3100  620000                0             1
# 12  3600  695000                0             1

# %%
# now lets create linear regression model...
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
x = final.drop("price",axis = "columns")
x
# Out:
#     area  monroe township  robbinsville
# 0   2600                1             0
# 1   3000                1             0
# 2   3200                1             0
# 3   3600                1             0
# 4   4000                1             0
# 5   2600                0             0
# 6   2800                0             0
# 7   3300                0             0
# 8   3600                0             0
# 9   2600                0             1
# 10  2900                0             1
# 11  3100                0             1
# 12  3600                0             1

# %%
y = final.price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
# x and y are ready...
# now we have to train the model...

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[2800,0,1]])
# Out:
# array([590775.63964739])

# %%
model.predict([[3400,0,0]])
# Out:
# array([681241.66845839])

# %%
model.score(x,y)
# Out:
# 0.9573929037221873

# %% [markdown]
# ## using sklearn LabelEncoder:

# %%
dff
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9      robbinsville  2600  575000
# 10     robbinsville  2900  600000
# 11     robbinsville  3100  620000
# 12     robbinsville  3600  695000

# %%
target = dff['price']

# %% [markdown]
# ### Label Encoding refers to converting the labels into a numeric form so as to convert them into the machine-readable form.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_town = LabelEncoder()

# %%
dff["Town"] = le_town.fit_transform(dff["town"])

# %%
dff
# Out:
#                town  area   price  Town
# 0   monroe township  2600  550000     0
# 1   monroe township  3000  565000     0
# 2   monroe township  3200  610000     0
# 3   monroe township  3600  680000     0
# 4   monroe township  4000  725000     0
# 5      west windsor  2600  585000     2
# 6      west windsor  2800  615000     2
# 7      west windsor  3300  650000     2
# 8      west windsor  3600  710000     2
# 9      robbinsville  2600  575000     1
# 10     robbinsville  2900  600000     1
# 11     robbinsville  3100  620000     1
# 12     robbinsville  3600  695000     1

# %%
inputs = dff.drop(["price","town"],axis="columns")

# %%
inputs
# Out:
#     area  Town
# 0   2600     0
# 1   3000     0
# 2   3200     0
# 3   3600     0
# 4   4000     0
# 5   2600     2
# 6   2800     2
# 7   3300     2
# 8   3600     2
# 9   2600     1
# 10  2900     1
# 11  3100     1
# 12  3600     1

# %%
target
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs,target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs,target)
# Out:
# 1.0

# %%
model.predict([[2300,0]])
# Out:
# array([550000], dtype=int64)
